# %%
f = open("data2.json", "w")

# %%
obj = {
    "users":[
        {"id":1, "name": "vivek", "friends":[2,3], "liked_pages": [101]},
        {"id":2, "name": "priya", "friends": [1,4],"liked_pages": [102]},
        {"id":3, "name": "", "friends":[1], "liked_pages":[104]},
        {"id":4, "name": "sara", "friends":[2,2], "liked_pages":[104]},
        {"id":5, "name": "amit", "friends":[], "liked_pages":[]}
    ],
    "pages":[
        {"id": 101, "name": "python developers"},
        {"id": 102, "name": "Data science"},
        {"id": 103, "name": "AI & ML community"},
        {"id": 104, "name": "web dev hub" },
        {"id": 104, "name": "web developement"}
    ],
}

# %%
json.dump(obj, f)

# %%
f.close()

# %%
#load the data

# %%
import json

# %%
def load_data(filename):
    with open(filename, "r") as f:
        data = json.load(f)
    return data


import json

def clean_data(data):
    #now will remove missing vakues of names from json file
    data["users"] = [user for user in data["users"] if user["name"].strip()]
    print("missing names has been succesfully deleted")
    
    #remove duplicate values
    for user in data["users"]:
        user["friends"] = list(set(user["friends"]))
    print("duplicate values has been removed succesfully")
    
    #remove inactive user
    data["users"] = [user for user in data["users"] if user["friends"] or user["liked_pages"]]
    print ("inactive users has been removed succesfully")
    #remove duplicate pages
    unique_pages = {}
    for page in data["pages"]:
        unique_pages[page["id"]] = list(unique_pages.values())
    print("duplicate pages has been removed succesfully")
    return data
data = json.load(open("data2.json"))
data = clean_data(data)
json.dump(data, open("cleaned_data2.json", "w"), indent = 4)
print("data has been deleted succesfully")

    return data
# Out:
# missing names has been succesfully deleted
# duplicate values has been removed succesfully
# inactive users has been removed succesfully
# duplicate pages has been removed succesfully
# data has been deleted succesfully

# %%
import json
def load_data(filename):
    with open(filename,"r") as f:
        dataa = json.load(f)
    return dataa

# %%
dataa = load_data("cleaned_data2.json")

# %%
dataa
# Out:
# {'users': [{'id': 1, 'name': 'vivek', 'friends': [2, 3], 'liked_pages': [101]},
#   {'id': 2, 'name': 'priya', 'friends': [1, 4], 'liked_pages': [102]},
#   {'id': 4, 'name': 'sara', 'friends': [2], 'liked_pages': [104]}],
#  'pages': [{'id': 101, 'name': 'python developers'},
#   {'id': 102, 'name': 'Data science'},
#   {'id': 103, 'name': 'AI & ML community'},
#   {'id': 104, 'name': 'web dev hub'},
#   {'id': 104, 'name': 'web developement'}]}

# %%
def display_users(dataa):
    print("users and their connections\n")
    for user in data["users"]:
        print(f"ID-{user['id']} {user['name']} is friends: with ID:{'friends'} and liked pages are {'liked_pages'}")
    print("\npages information")
    for page in data["pages"]:
        
        print(f"{page['id']} :{page['name']}")   
    
display_users(dataa)
# Out:
# users and their connections
#
# ID-1 vivek is friends: with ID:friends and liked pages are liked_pages
# ID-2 priya is friends: with ID:friends and liked pages are liked_pages
# ID-4 sara is friends: with ID:friends and liked pages are liked_pages
#
# pages information
# 101 :python developers
# 102 :Data science
# 103 :AI & ML community
# 104 :web dev hub
# 104 :web developement
