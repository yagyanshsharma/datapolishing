# %%
f = open("data.json", "w")

# %%
obj = {
    "users": [
        {"id": 1, "name": "ishan", "friends":[2,3], "liked_pages": [101]},
        {"id": 2, "name": "yagyansh", "friends":[1,4], "liked_pages":[102]},
        {"id": 3, "name": "rajat", "friends": [1], "liked_pages": [101,103]},
        {"id": 4, "name": "pragya", "friends": [2], "liked_pages":[104]}
    ],
    "pages":[
        {"id": 101, "name": "python developers"},
        {"id": 102, "name": "software developers"},
        {"id": 103, "name": "data scientis"},
        {"id": 104, "name": "web dev hub"}
    ]
}

# %%
json.dump(obj, f)

# %%
f.close()

# %%
import json

# %%
def load_data(filename):
    with open(filename, "r") as f:
        data = json.load(f)
    return data

# %%
data = load_data("data.json")

# %%
data
# Out:
# {'users': [{'id': 1, 'name': 'ishan', 'friends': [2, 3], 'liked_pages': [101]},
#   {'id': 2, 'name': 'yagyansh', 'friends': [1, 4], 'liked_pages': [102]},
#   {'id': 3, 'name': 'rajat', 'friends': [1], 'liked_pages': [101, 103]},
#   {'id': 4, 'name': 'pragya', 'friends': [2], 'liked_pages': [104]}],
#  'pages': [{'id': 101, 'name': 'python developers'},
#   {'id': 102, 'name': 'software developers'},
#   {'id': 103, 'name': 'data scientis'},
#   {'id': 104, 'name': 'web dev hub'}]}

# %%
def display_users(data):
    print("users and their connections\n")
    for user in data ['users']:
        print(f"ID-{user['id']} {user['name']} is friends with: ID:{user['friends']} and liked pages are {user['liked_pages']}")
    print("\npages information")
    for page in data ['pages']:
        print(f"{page['id']} : {page['name']}")

display_users(data)
# Out:
# users and their connections
#
# ID-1 ishan is friends with: ID:[2, 3] and liked pages are [101]
# ID-2 yagyansh is friends with: ID:[1, 4] and liked pages are [102]
# ID-3 rajat is friends with: ID:[1] and liked pages are [101, 103]
# ID-4 pragya is friends with: ID:[2] and liked pages are [104]
#
# pages information
# 101 : python developers
# 102 : software developers
# 103 : data scientis
# 104 : web dev hub
